# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Dataset Analysis

# %%
prices_df = pd.read_csv("datasets/house_prices/csv/prices.csv")
totals_df = pd.read_csv("datasets/house_prices/csv/totals.csv")

# %%
display(prices_df.head())

# Plot the total houses sold per year
totals_df["Total Houses Sold"] = totals_df["Total Finished Houses Sold"] + totals_df["Total Unfinished Houses Sold"]
totals_df["Total Average Price"] = (totals_df["National Average Price per m^2 of Finished Houses"] +
                                    totals_df["National Average Price per m^2 of Unfinished Houses"]) / 2

convert_range = lambda x: x.replace(" ", "").replace("€", "").split("-")

totals_df["National Average Range of Price per m^2 of Finished Houses"] = totals_df[
    "National Average Range of Price per m^2 of Finished Houses"].map(convert_range)

display(totals_df.head())

sns.set_theme()
sns.set_context("notebook")
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=totals_df, x="Year", y="Total Houses Sold", marker="o")
plt.title("Total houses sold per year")
plt.xlabel("Year")
plt.ylabel("Total")
plt.show()
# Out:
#      Commune      Canton  Finished Houses Sold Average price per m^2  \
# 0   Beaufort  Echternach                   4.0                     *
# 1       Bech  Echternach                   0.0                     *
# 2  Beckerich     Redange                   8.0                     *
# 3    Berdorf  Echternach                   6.0                     *
# 4  Bertrange  Luxembourg                  21.0              3908.121
#
#    m^2 price range  Unfinished Houses Sold  \
# 0                *                     0.0
# 1                *                     0.0
# 2                *                     0.0
# 3                *                     1.0
# 4  2829 € - 4720 €                    29.0
#
#   Average Unfinished Houses Price per m^2 Unfinished Houses m^2 price range  \
# 0                                       *                                 *
# 1                                       *                                 *
# 2                                       *                                 *
# 3                                       *                                 *
# 4                                4575.018                   3070 € - 5843 €
#
#    Year
# 0  2007
# 1  2007
# 2  2007
# 3  2007
# 4  2007
#    Year  Total Finished Houses Sold  \
# 0  2007                      2207.0
# 1  2008                      2026.0
# 2  2009                      2182.0
# 3  2010                      2302.0
# 4  2011                      2562.0
#
#    National Average Price per m^2 of Finished Houses  \
# 0                                           3507.182
# 1                                           3578.830
# 2                                           3488.124
# 3                                           3663.585
# 4                                           3858.319
#
#   National Average Range of Price per m^2 of Finished Houses  \
# 0                                       [2327, 4731]
# 1                                       [2273, 4978]
# 2                                       [2301, 4852]
# 3                                       [2438, 5142]
# 4                                       [2533, 5487]
#
#    Total Unfinished Houses Sold  \
# 0                        1307.0
# 1                        1254.0
# 2                         979.0
# 3                        1407.0
# 4                        1621.0
#
#    National Average Price per m^2 of Unfinished Houses  \
# 0                                           3945.805
# 1                                           4203.922
# 2                                           4264.941
# 3                                           4480.081
# 4                                           4633.802
#
#   National Average Range of Price per m^2 of Unfinished Houses  \
# 0                                    2733 € - 5478 €
# 1                                    2982 € - 5611 €
# 2                                    2894 € - 6203 €
# 3                                    3155 € - 6374 €
# 4                                    3232 € - 6448 €
#
#    Total Houses Sold  Total Average Price
# 0             3514.0            3726.4935
# 1             3280.0            3891.3760
# 2             3161.0            3876.5325
# 3             3709.0            4071.8330
# 4             4183.0            4246.0605
